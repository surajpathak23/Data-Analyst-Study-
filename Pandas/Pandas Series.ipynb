# %% [markdown]
# # 📘 Pandas Series – Cheat Sheet
#
# ## 🔹 Basics
# - `type(s)` → Series ka type check
# - `dir(s)` → Available functions & attributes
# - `len(s)` → Length of series
# - `list(s)` → Convert Series to list
# - `sorted(s)` → Sorted list of values
#
# ---
#
# ## 🔹 Attributes
# - `s.index` → Index (row labels)
# - `s.values` → Values as array
# - `s.dtype` → Data type of Series
# - `s.shape` → Shape (rows,)
# - `s.size` → Total elements
# - `s.ndim` → Dimensions (1D)
# - `s.is_unique` → Values unique hain ya nahi
#
# ---
#
# ## 🔹 Indexing & Slicing
# - `s[0]` → Single value
# - `s[1:5]` → Slice values
# - `s.loc[]` → Label-based indexing
# - `s.iloc[]` → Position-based indexing
# - `s[[0,2,3]]` → Fancy indexing (multiple values)
#
# ---
#
# ## 🔹 Head & Tail
# - `s.head()` → First 5 values
# - `s.tail()` → Last 5 values
#
# ---
#
# ## 🔹 Type Conversion
# - `s.astype('category')` → Change data type
#
# ---
#
# ## 🔹 Membership
# - `'value' in s.values` → Check value exist karta hai ya nahi
#
# ---
#
# ## 🔹 Operators
# - `100-s` → Arithmetic operation on all values
# - `s>=50` → Relational check (True/False)
#
# ---
#
# ## 🔹 Boolean Indexing
# - `s[s>50]` → Filter values
# - `(s==0).sum()` → Count zero values
#
# ---
#
# ## 🔹 Sorting & Counting
# - `s.sort_values()` → Sort values
# - `s.value_counts()` → Frequency count
# - `s.count()` → Non-missing values count
#
# ---
#
# ## 🔹 Aggregation
# - `s.max()` → Maximum
# - `s.min()` → Minimum
# - `s.mean()` → Average
# - `s.sum()` → Total sum
# - `s.product()` → Product of values
# - `s.describe()` → Summary stats
#
# ---
#
# ## 🔹 Uniqueness
# - `s.unique()` → Unique values
# - `s.nunique()` → Count of unique values
#
# ---
#
# ## 🔹 Missing Data
# - `s.isnull()` → NaN check
# - `s.notnull()` → Non-NaN check
# - `s.fillna(0)` → Replace NaN
# - `s.dropna()` → Remove NaN

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series from List (String Example)

# %%
name= ['Suraj','Jay','Shravan','Shivam']
pd.Series(name)
# Out:
# 0      Suraj
# 1        Jay
# 2    Shravan
# 3     Shivam
# dtype: object

# %% [markdown]
# ## Series from List (Integer Example)
#   - pd.Series(score) → List ko Series me convert karta hai

# %%
# Integer values se Series banana
score = [10, 40, 56, 72, 89]
pd.Series(score)
# Out:
# 0    10
# 1    40
# 2    56
# 3    72
# 4    89
# dtype: int64

# %% [markdown]
# ### Series with Custom `Index`
#   - Yaha humne custom index assign kiya hai (cricketers list).
#   - Default numeric index ke jagah cricketers ke naam show ho rahe hain.
#   - `pd.Series(data, index=...)` → is format me hum Series ke liye apna index define kar sakte hain.

# %%
# Custom index ke sath Series banana
runs=[34,56,78,100]
cricketers=['Virat','Rohit','Hardik','Dhoni']

pd.Series(runs,index=cricketers)
# Out:
# Virat      34
# Rohit      56
# Hardik     78
# Dhoni     100
# dtype: int64

# %% [markdown]
# ### Series with `name` Attribute
#   - name attribute se hum Series ka title/label de sakte hain.
#   - Isse Series ka purpose clear hota hai (yaha "Cricket Score").
#   - Output me ab Name: Cricket Score show ho raha hai.

# %%
# Series ko ek naam dena
cricket=pd.Series(runs,index=cricketers,name='Cricket Score')
cricket
# Out:
# Virat      34
# Rohit      56
# Hardik     78
# Dhoni     100
# Name: Cricket Score, dtype: int64

# %% [markdown]
# ### Series from Dictionary
#   - Dictionary se Series banane par:
#      - `Keys` → Index ban jate hain.
#      - `Values` → Data ban jate hain.
#   - Yaha subjects (math, hindi, English, science) index hain aur unke marks values hain.
#   - name='Student marks' → Series ka label assign kiya gaya hai.

# %%
# Dictionary se Series banana
score={
    'math':78,
    'hindi':56,
    'English':64,
    'science':75
}
marks=pd.Series(score,name='Student marks')
marks
# Out:
# math       78
# hindi      56
# English    64
# science    75
# Name: Student marks, dtype: int64

# %% [markdown]
# #Series Attribute

# %% [markdown]
# ### `.size `
#   - .size → Series me total number of elements (data items) ko return karta hai.

# %%
marks.size
# Out:
# 4

# %% [markdown]
# ### `.dtype`
#   - .dtype → Series ke elements ka data type batata hai.
#   - Yaha sabhi values integers hain → isliye output `int64`.
#   - Agar values string hoti to object aur `float` hoti to `float64` return hota.

# %%
marks.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### `.name`
#   - .name → Series ka label/naam return karta hai jo humne create karte waqt diya tha.
#   - Yaha humne name='Student marks' assign kiya tha → isliye output `Student marks`.
#   - Agar name assign na kiya ho to output `None` aata hai.

# %%
marks.name
# Out:
# 'Student marks'

# %% [markdown]
# ### `.is_unique`
#   - .is_unique → Boolean (True/False) return karta hai.
#   - Agar Series ke sabhi elements unique hain → `True`.
#   - Agar koi value duplicate hai → `False`.
#   - Yaha `marks` Series me sabhi subjects ke marks alag-alag hain → isliye output `True`.

# %%
marks.is_unique
# Out:
# True

# %% [markdown]
# ### `.is_unique` (False Example)
#   - .is_unique check karta hai ki sabhi values unique hain ya nahi.
#   - Yaha [1, 2, 1, 3, 4, 2] me 1 aur 2 repeat ho rahe hain.
#   - Isliye result False aaya.

# %%
pd.Series([1,2,1,3,4,2]).is_unique
# Out:
# False

# %% [markdown]
# ### `.index`
#   - .index → Series ke index labels return karta hai.
#   -  Yaha dictionary se Series banayi thi → subjects (math, hindi, English, science) index ban gaye.
#   -  Output me `dtype='object'` dikhata hai ki ye string type index hain.
#   -  Agar numeric index hota to uska type `int64` hota.

# %%
marks.index
# Out:
# Index(['math', 'hindi', 'English', 'science'], dtype='object')

# %% [markdown]
# ### `.values`
#   - `.values` → Series ke data values ko NumPy array ke form me return karta hai.
#   - Yaha marks ke values `[78, 56, 64, 75]` array ke roop me mile.
#   - Index isme include nahi hota, sirf values return hoti hain.

# %%
marks.values
# Out:
# array([78, 56, 64, 75])

# %% [markdown]
# ### Reading a CSV (DataFrame with 1 Column)
#   - `pd.read_csv('subs.csv')` → CSV file ko DataFrame me load karta hai.
#   - Agar CSV me sirf ek hi column ho → to DataFrame me bhi ek hi column hoga.
#   - Yaha `subs` ek DataFrame hai (Series nahi).
#   - DataFrame basically 2D labeled data structure hota hai → rows + columns.

# %%
kohli=pd.read_csv('kohli_ipl.csv')

# %%
""" This data indicates DataFrame """
subs = pd.read_csv('subs.csv')
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
# type(object) → kisi bhi Python object ka datatype/class return karta hai.
type(subs)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Converting DataFrame → Series using .squeeze()
#   - `.squeeze()` → Agar DataFrame me sirf ek hi column ho, to usse Series me convert kar deta hai.
#   - Yaha `subs` ek 1-column DataFrame tha → squeeze karne ke baad subs2 ek Series ban gaya.
#   - Isliye `type(subs2)` → `pandas.core.series.Series`.

# %%
subs2=subs.squeeze()
type(subs2)
# Out:
# pandas.core.series.Series

# %%
type(kohli)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Using .set_index() with .squeeze()
#   - `.set_index('match_no')` → DataFrame me `match_no` column ko index bana diya.
#   - `.squeeze()` → Kyunki ab DataFrame me ek hi column bacha (`runs`), usse - Series me convert kar diya.
#   - Result ek Series hai jisme index = `match_no` aur values = `runs`.
#   - `Name: runs` → Series ka naam (column ka naam) show ho raha hai.

# %%
kohli2=kohli.set_index('match_no').squeeze()
kohli2
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
type(kohli2)
# Out:
# pandas.core.series.Series

# %%
bolly=pd.read_csv('bollywood.csv')
bolly
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
type(bolly)
# Out:
# pandas.core.frame.DataFrame

# %%
bolly2=bolly.set_index('movie').squeeze()
bolly2
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
type(bolly2)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #Series Method

# %% [markdown]
# ### `.head()` Method
#   - `.head()` → top 5 rows return karta hai by default.
#   - Useful jab hum large dataset ke sirf starting records dekhna chahte hain.

# %%
bolly.head()
# Out:
#                                   movie              lead
# 0              Uri: The Surgical Strike     Vicky Kaushal
# 1                         Battalion 609       Vicky Ahuja
# 2  The Accidental Prime Minister (film)       Anupam Kher
# 3                       Why Cheat India     Emraan Hashmi
# 4                       Evening Shadows  Mona Ambegaonkar

# %%
kohli.head(7)
# Out:
#    match_no  runs
# 0         1     1
# 1         2    23
# 2         3    13
# 3         4    12
# 4         5     1
# 5         6     9
# 6         7    34

# %% [markdown]
# ### `.tail()` Method
# - `.tail()` → last 5 rows return karta hai by default.
# - Large dataset me jab hume **ending records** dekhne ho tab useful hai.
# - Example: `subs.tail()` → `subs` DataFrame ki last 5 rows show karega.

# %%
subs.tail()
# Out:
#      Subscribers gained
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172

# %%
bolly.tail(9)
# Out:
#                            movie              lead
# 1491          Zameen (2003 film)        Ajay Devgn
# 1492  Waisa Bhi Hota Hai Part II      Arshad Warsi
# 1493    Devdas (2002 Hindi film)    Shah Rukh Khan
# 1494                      Kaante  Amitabh Bachchan
# 1495      Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496         Aankhen (2002 film)  Amitabh Bachchan
# 1497             Saathiya (film)      Vivek Oberoi
# 1498              Company (film)        Ajay Devgn
# 1499        Awara Paagal Deewana      Akshay Kumar

# %% [markdown]
# ### `.sample()` Method
# - `.sample()` → dataset se **random row/rows** return karta hai.
# - By default 1 random row deta hai.
# - Useful jab hume dataset ka **random observation** dekhna ho.
# - Example: `kohli.sample()` → `kohli` DataFrame se 1 random row show karega.

# %%
kohli.sample()
# Out:
#      match_no  runs
# 121       122    52

# %%
bolly.sample(6)
# Out:
#                                      movie               lead
# 392                               Hunterrr    Gulshan Devaiah
# 977                    Dostana (2008 film)  Abhishek Bachchan
# 2     The Accidental Prime Minister (film)        Anupam Kher
# 1401      Shukriya: Till Death Do Us Apart        Anupam Kher
# 770                             404 (film)         Sara Arjun
# 27                      The Tashkent Files   Naseeruddin Shah

# %% [markdown]
# ### `.value_counts()` Method
# - `.value_counts()` → column me unique values ka **frequency count** return karta hai.
# - Data ko summarize karne aur **most common values** dekhne ke liye useful hai.
# - Example: `bolly['lead'].value_counts()` → `lead` column me har actor/actress kitni baar aaya hai, uska count dikhata hai.
# - ye `descending order` me value deta hai

# %%
bolly['lead'].value_counts()
# Out:
# lead
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Seema Azmi            1
# Akanksha Puri         1
# Charanpreet Insan     1
# Jaideep Ahlawat       1
# Monali Thakur         1
# Name: count, Length: 566, dtype: int64

# %% [markdown]
# ### `.sort_values()` Method
# - `.sort_values()` → DataFrame/Series ko kisi **column ke values ke basis par sort** karta hai.
# - By default ascending order me sort hota hai.
# - Example: `kohli.sort_values('runs')` → `kohli` DataFrame ko `runs` column ke values ke hisaab se ascending order me arrange karega.
# - Agar descending order chahiye ho to:
#   ```python
#   kohli.sort_values('runs', ascending=False)

# %%
kohli.sort_values('runs')
# Out:
#      match_no  runs
# 7           8     0
# 86         87     0
# 92         93     0
# 90         91     0
# 205       206     0
# ..        ...   ...
# 163       164   100
# 119       120   100
# 122       123   108
# 125       126   109
# 127       128   113
#
# [215 rows x 2 columns]

# %%
kohli.sort_values('runs',ascending=False)
# Out:
#      match_no  runs
# 127       128   113
# 125       126   109
# 122       123   108
# 119       120   100
# 163       164   100
# ..        ...   ...
# 92         93     0
# 129       130     0
# 205       206     0
# 206       207     0
# 210       211     0
#
# [215 rows x 2 columns]

# %% [markdown]
# ### Top 5 Runs using `.sort_values()` + `.head()`
# - `kohli.sort_values('runs', ascending=False)` → `runs` column ke basis par data ko **descending order** me sort karega.
# - `.head()` → top 5 rows return karega.
# - Combined: `kohli.sort_values('runs', ascending=False).head()` → Kohli ke IPL data me **top 5 highest runs wali rows** show karega.

# %%
kohli.sort_values('runs',ascending=False).head()
# Out:
#      match_no  runs
# 127       128   113
# 125       126   109
# 122       123   108
# 119       120   100
# 163       164   100

# %% [markdown]
# ### Extract Top Run Value Only
# - `kohli.sort_values('runs', ascending=False)` → `runs` ke basis par data ko descending order me arrange karega.
# - `.head(1)` → top 1 row return karega (highest run wali).
# - `.values[0]` → us row ka **sirf numpy array format me values** extract karega.
# - Example: `kohli.sort_values('runs', ascending=False).head(1).values[0]` → Kohli ke sabse highest run wali row ke saare column values return karega (numpy array ke form me).

# %%
kohli.sort_values('runs',ascending=False).head(1).values[0]
# Out:
# array([128, 113])

# %% [markdown]
# ### `.sort_values()` on "Subscribers gained" (Descending Order)
# - `.sort_values('Subscribers gained', ascending=False)` → Data ko `Subscribers gained` column ke values ke basis par **descending order** me sort karega.
# - Isse hume pata chalega ki **kis channel ne sabse zyada subscribers gain kiye hain**.
# - Example: `subs.sort_values('Subscribers gained', ascending=False)` → `subs` DataFrame ko highest → lowest subscribers gained ke order me arrange karega.

# %%
subs.sort_values('Subscribers gained',ascending=False)
# Out:
#      Subscribers gained
# 330                 396
# 331                 312
# 168                 306
# 233                 301
# 280                 295
# ..                  ...
# 14                   39
# 19                   37
# 24                   35
# 6                    33
# 42                   33
#
# [365 rows x 1 columns]

# %% [markdown]
# ### `.sort_values()` with `inplace=True`
# - `inplace=True` → changes ko **original DataFrame me directly apply** kar deta hai, naya copy return nahi karta.

# %%
kohli.sort_values('runs',inplace=True)
kohli
# Out:
#      match_no  runs
# 7           8     0
# 86         87     0
# 92         93     0
# 90         91     0
# 205       206     0
# ..        ...   ...
# 163       164   100
# 119       120   100
# 122       123   108
# 125       126   109
# 127       128   113
#
# [215 rows x 2 columns]

# %% [markdown]
# ### `.sort_values()` on "movie" Column with `inplace=True`
# - `.sort_values('movie', ascending=False, inplace=True)` → `movie` column ke basis par data ko **descending alphabetical order** me sort karega.
# - `inplace=True` → sorting ka effect **directly original DataFrame** par apply hoga.

# %%
bolly.sort_values('movie',ascending=False, inplace=True)
bolly
# Out:
#                          movie                lead
# 941      Zor Lagaa Ke...Haiya!       Meghan Jadhav
# 758                   Zokkomon     Darsheel Safary
# 672          Zindagi Tere Naam  Mithun Chakraborty
# 780   Zindagi Na Milegi Dobara      Hrithik Roshan
# 603              Zindagi 50-50         Veena Malik
# ...                        ...                 ...
# 484       2 States (2014 film)        Arjun Kapoor
# 1040          1971 (2007 film)      Manoj Bajpayee
# 725     1920: The Evil Returns         Vicky Ahuja
# 287               1920: London       Sharman Joshi
# 1022               1920 (film)    Rajniesh Duggall
#
# [1500 rows x 2 columns]

# %% [markdown]
# #Series Maths Methods

# %% [markdown]
# ### `.count()` Method
# - `.count()` → column me **non-missing (NaN ke alawa)** values ki counting karta hai.
# - Agar column me missing values (NaN) ho to unhe **ignore** karta hai.

# %%
subs.count()
# Out:
# Subscribers gained    365
# dtype: int64

# %% [markdown]
# ### `.sum()` Method
# - `.sum()` → column ke saare **numerical values ka total** calculate karta hai.
# - Useful jab hume **overall total** ya **aggregate value** chahiye ho.

# %%
subs.sum()
# Out:
# Subscribers gained    49510
# dtype: int64

# %% [markdown]
# ### `.product()` Method
# - `.product()` → column ke saare **numerical values ko multiply** karke ek single result return karta hai.
# - Rarely use hota hai, mostly mathematical/statistical calculation me.

# %%
subs.product()
# Out:
# Subscribers gained    0
# dtype: int64

# %% [markdown]
# ## mean -> median -> mode -> std -> var

# %%
print("Subs Mean : ",subs.mean())
print("Subs Median : ",subs.median())
print("Subs Mode: ",subs.mode())
print("Subs Standard Variance : ",subs.std())
print("Subs Variance : ",subs.var())
# Out:
# Subs Mean :  Subscribers gained    135.643836
# dtype: float64
# Subs Median :  Subscribers gained    123.0
# dtype: float64
# Subs Mode:     Subscribers gained
# 0                 105
# Subs Standard Variance :  Subscribers gained    62.675023
# dtype: float64
# Subs Variance :  Subscribers gained    3928.158513
# dtype: float64

# %% [markdown]
# ### Min/Max

# %%
print("Minimum of Sub : ",subs.min())
print("Maximum of Sub : ",subs.max())
# Out:
# Minimum of Sub :  Subscribers gained    33
# dtype: int64
# Maximum of Sub :  Subscribers gained    396
# dtype: int64

# %% [markdown]
# ### `.describe()` Method
# - `.describe()` → column ke liye **statistical summary** provide karta hai.
# - Isme mainly yeh details hoti hain:
#   - **count** → non-missing values ka count
#   - **mean** → average value
#   - **std** → standard deviation (spread of data)
#   - **min** → minimum value
#   - **25%** → first quartile (Q1)
#   - **50%** → median (Q2)
#   - **75%** → third quartile (Q3)
#   - **max** → maximum value

# %%
subs.describe()
# Out:
#        Subscribers gained
# count          365.000000
# mean           135.643836
# std             62.675023
# min             33.000000
# 25%             88.000000
# 50%            123.000000
# 75%            177.000000
# max            396.000000

# %% [markdown]
# ### Load Dataset

# %%
kohli=pd.read_csv('kohli_ipl.csv')
bolly=pd.read_csv('bollywood.csv')
subs=pd.read_csv('subs.csv')

# %% [markdown]
# # Series Indexing
# - Pandas Series me by default **integer indexing** hota hai (0,1,2,3...).
# - Jab hum list ko `pd.Series()` me convert karte hain to automatically index assign ho jata hai.

# %%
# integer indexing
x=pd.Series([13,42,36,74,95,66,78,98])
x[2]
# Out:
# np.int64(36)

# %%
# negative indexing

# %% [markdown]
# ## Series Slicing
# - Pandas me slicing **Python list slicing** jaisa hi hota hai.
# - Syntax: `object[start:end:step]`
#   - **start** → starting index (inclusive)
#   - **end** → ending index (exclusive)
#   - **step** → kitne step ke gap me values pick karni hain

# %%
kohli[5:17]
# Out:
#     match_no  runs
# 5          6     9
# 6          7    34
# 7          8     0
# 8          9    21
# 9         10     3
# 10        11    10
# 11        12    38
# 12        13     3
# 13        14    11
# 14        15    50
# 15        16     2
# 16        17    22

# %%
# negative slicing
kohli[-3:]
# Out:
#      match_no  runs
# 212       213    73
# 213       214    25
# 214       215     7

# %%
# slicing in movie data
bolly[4:9]
# Out:
#                               movie                  lead
# 4                   Evening Shadows      Mona Ambegaonkar
# 5                       Soni (film)  Geetika Vidya Ohlyan
# 6                     Fraud Saiyaan          Arshad Warsi
# 7                        Bombairiya          Radhika Apte
# 8  Manikarnika: The Queen of Jhansi        Kangana Ranaut

# %%
bolly[7:20:2]
# Out:
#                 movie                 lead
# 7          Bombairiya         Radhika Apte
# 9    Thackeray (film)  Nawazuddin Siddiqui
# 11          Gully Boy        Ranveer Singh
# 13      Total Dhamaal           Ajay Devgn
# 15  Badla (2019 film)     Amitabh Bachchan
# 17       Hamid (film)   Talha Arshad Reshi
# 19          Risknamaa       Garima Agarwal

# %% [markdown]
# ### Fancy Indexing with `.iloc[]`
# - **Fancy Indexing** → ek saath multiple specific indexes ki values access karna.
# - `.iloc[]` → purely **integer-based indexing** ke liye use hota hai.

# %%
kohli.iloc[[0,1,3,4,5]]
# Out:
#    match_no  runs
# 0         1     1
# 1         2    23
# 3         4    12
# 4         5     1
# 5         6     9

# %% [markdown]
# ### Fancy Indexing with Labels using `.loc[]`
# - `.set_index('column')` → kisi column ko **index** bana deta hai.
# - `.loc[]` → label-based indexing ke liye use hota hai.

# %%
bolly_indexed = bolly.set_index('movie')
bolly_indexed.loc['Hum Tumhare Hain Sanam']
# Out:
# lead    Shah Rukh Khan
# Name: Hum Tumhare Hain Sanam, dtype: object

# %% [markdown]
# # Editing Series

# %% [markdown]
# ### Creating Series from Dictionary
# - Pandas Series ko dictionary ke through bhi banaya ja sakta hai.
# - Dictionary ke keys → **index ban jaate hain**
# - Dictionary ke values → **data ban jaata hai**
# - `name` parameter se Series ka naam set kar sakte hain.

# %%
# sample data
marks={
    'math':78,
    'hindi':56,
    'English':64,
    'science':75
}
marks=pd.Series(marks,name="Suraj's Marks")
marks
# Out:
# math       78
# hindi      56
# English    64
# science    75
# Name: Suraj's Marks, dtype: int64

# %% [markdown]
# ### Updating Series using Indexing
# - Pandas Series me index ke through directly **value update** kar sakte hain.

# %%
marks[1]=100
marks
# Out:
# /tmp/ipython-input-1043635770.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks[1]=100
# math        78
# hindi      100
# English     64
# science     75
# Name: Suraj's Marks, dtype: int64

# %% [markdown]
# ### Adding New Value using Label
# - Agar Series me koi label (index) exist nahi karta hai, to usse **naya entry add** kiya ja sakta hai.

# %%
marks['biology']=95
marks
# Out:
# math        78
# hindi      100
# English     64
# science     75
# biology     95
# Name: Suraj's Marks, dtype: int64

# %% [markdown]
# ####  sample data

# %%
runs=pd.Series([13,14,15,16])
runs
# Out:
# 0    13
# 1    14
# 2    15
# 3    16
# dtype: int64

# %% [markdown]
# ### Updating Series using Slicing
# - Pandas Series me slicing ke through ek saath **multiple values update** kar sakte hain.

# %%
runs[2:4]=[4,9]
runs
# Out:
# 0    13
# 1    14
# 2     4
# 3     9
# dtype: int64

# %% [markdown]
# ### Updating Series using Fancy Indexing
# - Fancy Indexing ke through ek saath **multiple specific indexes** ki values update ki ja sakti hain.

# %%
runs[[0,2,3]]=[0,0,0]
runs
# Out:
# 0     0
# 1    14
# 2     0
# 3     0
# dtype: int64

# %%
bolly.head()
# Out:
#                                   movie              lead
# 0              Uri: The Surgical Strike     Vicky Kaushal
# 1                         Battalion 609       Vicky Ahuja
# 2  The Accidental Prime Minister (film)       Anupam Kher
# 3                       Why Cheat India     Emraan Hashmi
# 4                       Evening Shadows  Mona Ambegaonkar

# %% [markdown]
# ### Updating DataFrame Value using `.loc[]` with Condition
# - `.loc[condition, 'column'] = new_value` → condition ke basis par specific column ki value update karta hai.
# - Condition: bolly['movie'] == 'Battalion 609' → jaha movie ka naam "Battalion 609" hoga.
# - Update: us row me movie column ki value change hoke "dhamal" ban jaayegi.

# %%
bolly.loc[bolly['movie'] == 'Battalion 609', 'movie'] = 'dhamal'
bolly.head()
# Out:
#                                   movie              lead
# 0              Uri: The Surgical Strike     Vicky Kaushal
# 1                                dhamal       Vicky Ahuja
# 2  The Accidental Prime Minister (film)       Anupam Kher
# 3                       Why Cheat India     Emraan Hashmi
# 4                       Evening Shadows  Mona Ambegaonkar

# %% [markdown]
# #Copy and View

# %% [markdown]
# # Series with Python Functionalities

# %% [markdown]
# ### Python Built-in Functions with Pandas Objects
#
# 1. **`len(object)`**
#    - DataFrame/Series me kitni rows hain, uska count deta hai.
#    - Example: `len(subs)` → `subs` DataFrame ki total rows ka number.
#
# 2. **`type(object)`**
#    - Object ka data type batata hai.
#    - Example: `type(subs)` → `<class 'pandas.core.frame.DataFrame'>`.
#
# 3. **`dir(object)`**
#    - Object ke saare available **methods & attributes** ki list return karta hai.
#    - Example: `dir(subs)` → Pandas DataFrame ke methods (jaise `head`, `tail`, `sort_values`, etc.).
#
# 4. **`sorted(object)`**
#    - Columns ko **alphabetical order** me sort karke list deta hai.
#    - Example: `sorted(subs)` → `subs` ke columns sorted list me.
#
# 5. **`max(object)`**
#    - Columns ke labels me se **maximum (last in alphabetical order)** return karta hai.
#    - Example: `max(subs)` → alphabetically last column name.
#
# 6. **`min(object)`**
#    - Columns ke labels me se **minimum (first in alphabetical order)** return karta hai.
#    - Example: `min(subs)` → alphabetically first column name.

# %%
# len/type/dir/sorted/max/min
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(max(subs))
print(min(subs))
# Out:
# 365
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# # Type Conversion

# %%
marks
# Out:
# math        78
# hindi      100
# English     64
# science     75
# biology     95
# Name: Suraj's Marks, dtype: int64

# %% [markdown]
# ### Type Conversion: Series → List
# - Pandas Series ko Python list me convert karne ke liye `list()` function use hota hai.
# - Conversion ke baad sirf **index nahi**, balki **sirf values** list me store hoti hain.

# %%
list(marks)
# Out:
# [78, 100, 64, 75, 95]

# %% [markdown]
# ### Type conversion in dict

# %%
dict(marks)
# Out:
# {'math': np.int64(78),
#  'hindi': np.int64(100),
#  'English': np.int64(64),
#  'science': np.int64(75),
#  'biology': np.int64(95)}

# %%
bolly2 = bolly.set_index('movie')
bolly2
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# dhamal                                     Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %% [markdown]
# ### Membership Operator (`in`) with DataFrame
# - Python ka `in` operator use karke check kar sakte hain ki koi **column name** DataFrame me exist karta hai ya nahi.

# %%
'Awara Paagal Deewana' in bolly2
# Out:
# False

# %% [markdown]
# ### looping

# %%
# for i in bolly.index:
#   print(i)

# %%
marks
# Out:
# math        78
# hindi      100
# English     64
# science     75
# biology     95
# Name: Suraj's Marks, dtype: int64

# %% [markdown]
# ### Arithmetic Operation on Series
# - Pandas Series par directly arithmetic operators apply kar sakte hain.
# - Har subject ke marks ko 100 me se minus karega.
# - Output batayega ki 100 se kitna kam score kiya gaya hai.

# %%
100-marks
# Out:
# math       22
# hindi       0
# English    36
# science    25
# biology     5
# Name: Suraj's Marks, dtype: int64

# %% [markdown]
# ### Relational Operators on Series/DataFrame
# - Relational operators (>, <, >=, <=, ==, !=) element-wise comparison karte hain.- kohli DataFrame ke runs column ki har value check karega.
# - Agar value 50 ya usse zyada hai → True
# - Agar value 50 se kam hai → False

# %%
kohli['runs'] >= 50
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 210    False
# 211    False
# 212     True
# 213    False
# 214    False
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# # Practice Questions

# %%
kohli.size
# Out:
# 430

# %%
kohli.shape
# Out:
# (215, 2)

# %%
# ye batata hai ki kitne bar 50 se jyada runs mara hai
fifties = kohli[(kohli['runs'] >= 50)]
fifties.size

# ye adjust value nhi batayega ki kohli 50's se jyada run kitni bar mara hai
# Out:
# 100

# %%
fifties = kohli[(kohli['runs'] >= 50)].shape[0]
fifties

# It's give a correct value of 50's greater run by kohli
# Out:
# 50

# %%
# Count of 50s (between 50 and 99)
fifties = kohli[(kohli['runs'] >= 50) & (kohli['runs'] < 100)].shape[0]

# Count of 100s (100 or more)
hundreds = kohli[kohli['runs'] >= 100].shape[0]

print("50s:", fifties)
print("100s:", hundreds)
# Out:
# 50s: 45
# 100s: 5

# %%
# find number of duck
kohli[kohli['runs'] == 0].size
# Out:
# 18

# %%
# Count number of day when I had more than 200 subs a day
subs[subs['Subscribers gained'] > 200].size
# Out:
# 59

# %%
# Find actors who have done more than 20 movies
new_bolly= bolly.value_counts('lead')
new_bolly
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Naveen Bawa          1
# Naushaad Abbas       1
# Nauheed Cyrusi       1
# Natalia Janoszek     1
# Nishikant Kamat      1
# Name: count, Length: 566, dtype: int64

# %%
new_bolly.sample()
# Out:
# lead
# Viineet Kumar    1
# Name: count, dtype: int64

# %%
print(new_bolly > 20)              # its give answer in boolean value
print(" ")
print("<<--Show the value in Integer :-->> ")
print(new_bolly[new_bolly > 20])   #new_bolly[new_bolly>20]  # its give the answer of integer value
# Out:
# lead
# Akshay Kumar         True
# Amitabh Bachchan     True
# Ajay Devgn           True
# Salman Khan          True
# Sanjay Dutt          True
#                     ...
# Naveen Bawa         False
# Naushaad Abbas      False
# Nauheed Cyrusi      False
# Natalia Janoszek    False
# Nishikant Kamat     False
# Name: count, Length: 566, dtype: bool
#
# <<--Show the value in Integer :-->>
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# # Plotting Graphs on Series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
bolly.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='movie,lead'>

# %%
bolly.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
